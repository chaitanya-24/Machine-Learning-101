# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, RepeatVector
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
text = """

What is deep learning?
Deep learning is a subset of machine learning that uses multi-layered neural networks, called deep neural networks, to simulate the complex decision-making power of the human brain. Some form of deep learning powers most of the artificial intelligence (AI) in our lives today.

By strict definition, a deep neural network, or DNN, is a neural network with three or more layers. In practice, most DNNs have many more layers. DNNs are trained on large amounts of data to identify and classify phenomena, recognize patterns and relationships, evaluate posssibilities, and make predictions and decisions. While a single-layer neural network can make useful, approximate predictions and decisions, the additional layers in a deep neural network help refine and optimize those outcomes for greater accuracy.

Deep learning drives many applications and services that improve automation, performing analytical and physical tasks without human intervention. It lies behind everyday products and services—e.g., digital assistants, voice-enabled TV remotes,  credit card fraud detection—as well as still emerging technologies such as self-driving cars and generative AI.

Deep learning vs. machine learning
If deep learning is a subset of machine learning, how do they differ? Deep learning distinguishes itself from classical machine learning by the type of data that it works with and the methods in which it learns.

Machine learning algorithms leverage structured, labeled data to make predictions—meaning that specific features are defined from the input data for the model and organized into tables. This doesn’t necessarily mean that it doesn’t use unstructured data; it just means that if it does, it generally goes through some pre-processing to organize it into a structured format.

Deep learning eliminates some of data pre-processing that is typically involved with machine learning. These algorithms can ingest and process unstructured data, like text and images, and it automates feature extraction, removing some of the dependency on human experts. For example, let’s say that we had a set of photos of different pets, and we wanted to categorize by “cat”, “dog”, “hamster”, et cetera. Deep learning algorithms can determine which features (e.g. ears) are most important to distinguish each animal from another. In machine learning, this hierarchy of features is established manually by a human expert.

Then, through the processes of gradient descent and backpropagation, the deep learning algorithm adjusts and fits itself for accuracy, allowing it to make predictions about a new photo of an animal with increased precision.

Machine learning and deep learning models are capable of different types of learning as well, which are usually categorized as supervised learning, unsupervised learning, and reinforcement learning. Supervised learning utilizes labeled datasets to categorize or make predictions; this requires some kind of human intervention to label input data correctly. In contrast, unsupervised learning doesn’t require labeled datasets, and instead, it detects patterns in the data, clustering them by any distinguishing characteristics. Reinforcement learning is a process in which a model learns to become more accurate for performing an action in an environment based on feedback in order to maximize the reward.

How deep learning works
Deep learning neural networks, or artificial neural networks, attempts to mimic the human brain through a combination of data inputs, weights, and bias. These elements work together to accurately recognize, classify, and describe objects within the data.

Deep neural networks consist of multiple layers of interconnected nodes, each building upon the previous layer to refine and optimize the prediction or categorization. This progression of computations through the network is called forward propagation. The input and output layers of a deep neural network are called visible layers. The input layer is where the deep learning model ingests the data for processing, and the output layer is where the final prediction or classification is made.

Another process called backpropagation uses algorithms, like gradient descent, to calculate errors in predictions and then adjusts the weights and biases of the function by moving backwards through the layers in an effort to train the model. Together, forward propagation and backpropagation allow a neural network to make predictions and correct for any errors accordingly. Over time, the algorithm becomes gradually more accurate.

The above describes the simplest type of deep neural network in the simplest terms. However, deep learning algorithms are incredibly complex, and there are different types of neural networks to address specific problems or datasets. For example,

Convolutional neural networks (CNNs), used primarily in computer vision and image classification applications, can detect features and patterns within an image, enabling tasks, like object detection or recognition. In 2015, a CNN bested a human in an object recognition challenge for the first time.
Recurrent neural network (RNNs) are typically used in natural language and speech recognition applications as it leverages sequential or times series data.

Deep learning applications
Real-world deep learning applications are a part of our daily lives, but in most cases, they are so well-integrated into products and services that users are unaware of the complex data processing that is taking place in the background. Some of these examples include the following:

Law enforcement

Deep learning algorithms can analyze and learn from transactional data to identify dangerous patterns that indicate possible fraudulent or criminal activity. Speech recognition, computer vision, and other deep learning applications can improve the efficiency and effectiveness of investigative analysis by extracting patterns and evidence from sound and video recordings, images, and documents, which helps law enforcement analyze large amounts of data more quickly and accurately.

Financial services

Financial institutions regularly use predictive analytics to drive algorithmic trading of stocks, assess business risks for loan approvals, detect fraud, and help manage credit and investment portfolios for clients.

Customer service

Many organizations incorporate deep learning technology into their customer service processes. Chatbots—used in a variety of applications, services, and customer service portals—are a straightforward form of AI. Traditional chatbots use natural language and even visual recognition, commonly found in call center-like menus. However, more sophisticated chatbot solutions attempt to determine, through learning, if there are multiple responses to ambiguous questions. Based on the responses it receives, the chatbot then tries to answer these questions directly or route the conversation to a human user.

Virtual assistants like Apple's Siri, Amazon Alexa, or Google Assistant extends the idea of a chatbot by enabling speech recognition functionality. This creates a new method to engage users in a personalized way.

Healthcare

The healthcare industry has benefited greatly from deep learning capabilities ever since the digitization of hospital records and images. Image recognition applications can support medical imaging specialists and radiologists, helping them analyze and assess more images in less time.

"""

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([text])

# %%
tokenizer.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'learning': 3,
#  'of': 4,
#  'deep': 5,
#  'to': 6,
#  'a': 7,
#  'in': 8,
#  'data': 9,
#  'neural': 10,
#  'are': 11,
#  'it': 12,
#  'is': 13,
#  'or': 14,
#  'that': 15,
#  'for': 16,
#  'network': 17,
#  'machine': 18,
#  'human': 19,
#  'by': 20,
#  'applications': 21,
#  'networks': 22,
#  'more': 23,
#  'layers': 24,
#  'can': 25,
#  'recognition': 26,
#  'some': 27,
#  'make': 28,
#  'predictions': 29,
#  'from': 30,
#  'algorithms': 31,
#  'through': 32,
#  'an': 33,
#  'patterns': 34,
#  'as': 35,
#  'which': 36,
#  'this': 37,
#  'like': 38,
#  'called': 39,
#  'most': 40,
#  'with': 41,
#  'on': 42,
#  'layer': 43,
#  'services': 44,
#  'features': 45,
#  'input': 46,
#  'model': 47,
#  'into': 48,
#  'processing': 49,
#  'these': 50,
#  'images': 51,
#  'complex': 52,
#  'ai': 53,
#  'many': 54,
#  'well': 55,
#  'if': 56,
#  'labeled': 57,
#  'doesn’t': 58,
#  'use': 59,
#  'process': 60,
#  'different': 61,
#  'then': 62,
#  'backpropagation': 63,
#  'datasets': 64,
#  'time': 65,
#  'image': 66,
#  'speech': 67,
#  'analyze': 68,
#  'customer': 69,
#  'service': 70,
#  'chatbot': 71,
#  'subset': 72,
#  'uses': 73,
#  'brain': 74,
#  'form': 75,
#  'artificial': 76,
#  'our': 77,
#  'lives': 78,
#  'dnns': 79,
#  'large': 80,
#  'amounts': 81,
#  'identify': 82,
#  'classify': 83,
#  'recognize': 84,
#  'decisions': 85,
#  'help': 86,
#  'refine': 87,
#  'optimize': 88,
#  'accuracy': 89,
#  'improve': 90,
#  'performing': 91,
#  'tasks': 92,
#  'intervention': 93,
#  'products': 94,
#  'g': 95,
#  'assistants': 96,
#  'credit': 97,
#  'fraud': 98,
#  'how': 99,
#  'they': 100,
#  'itself': 101,
#  'type': 102,
#  'works': 103,
#  'learns': 104,
#  'structured': 105,
#  'specific': 106,
#  'unstructured': 107,
#  'pre': 108,
#  'typically': 109,
#  'example': 110,
#  'we': 111,
#  'categorize': 112,
#  'determine': 113,
#  'each': 114,
#  'animal': 115,
#  'another': 116,
#  'processes': 117,
#  'gradient': 118,
#  'descent': 119,
#  'algorithm': 120,
#  'adjusts': 121,
#  'new': 122,
#  'types': 123,
#  'supervised': 124,
#  'unsupervised': 125,
#  'reinforcement': 126,
#  'them': 127,
#  'any': 128,
#  'accurate': 129,
#  'based': 130,
#  'weights': 131,
#  'together': 132,
#  'accurately': 133,
#  'within': 134,
#  'multiple': 135,
#  'prediction': 136,
#  'forward': 137,
#  'propagation': 138,
#  'output': 139,
#  'where': 140,
#  'classification': 141,
#  'errors': 142,
#  'simplest': 143,
#  'however': 144,
#  'there': 145,
#  'used': 146,
#  'computer': 147,
#  'vision': 148,
#  'detect': 149,
#  'enabling': 150,
#  'object': 151,
#  'natural': 152,
#  'language': 153,
#  'users': 154,
#  'law': 155,
#  'enforcement': 156,
#  'financial': 157,
#  'assess': 158,
#  'responses': 159,
#  'questions': 160,
#  'healthcare': 161,
#  'what': 162,
#  'multi': 163,
#  'layered': 164,
#  'simulate': 165,
#  'decision': 166,
#  'making': 167,
#  'power': 168,
#  'powers': 169,
#  'intelligence': 170,
#  'today': 171,
#  'strict': 172,
#  'definition': 173,
#  'dnn': 174,
#  'three': 175,
#  'practice': 176,
#  'have': 177,
#  'trained': 178,
#  'phenomena': 179,
#  'relationships': 180,
#  'evaluate': 181,
#  'posssibilities': 182,
#  'while': 183,
#  'single': 184,
#  'useful': 185,
#  'approximate': 186,
#  'additional': 187,
#  'those': 188,
#  'outcomes': 189,
#  'greater': 190,
#  'drives': 191,
#  'automation': 192,
#  'analytical': 193,
#  'physical': 194,
#  'without': 195,
#  'lies': 196,
#  'behind': 197,
#  'everyday': 198,
#  'services—e': 199,
#  'digital': 200,
#  'voice': 201,
#  'enabled': 202,
#  'tv': 203,
#  'remotes': 204,
#  'card': 205,
#  'detection—as': 206,
#  'still': 207,
#  'emerging': 208,
#  'technologies': 209,
#  'such': 210,
#  'self': 211,
#  'driving': 212,
#  'cars': 213,
#  'generative': 214,
#  'vs': 215,
#  'do': 216,
#  'differ': 217,
#  'distinguishes': 218,
#  'classical': 219,
#  'methods': 220,
#  'leverage': 221,
#  'predictions—meaning': 222,
#  'defined': 223,
#  'organized': 224,
#  'tables': 225,
#  'necessarily': 226,
#  'mean': 227,
#  'just': 228,
#  'means': 229,
#  'does': 230,
#  'generally': 231,
#  'goes': 232,
#  'organize': 233,
#  'format': 234,
#  'eliminates': 235,
#  'involved': 236,
#  'ingest': 237,
#  'text': 238,
#  'automates': 239,
#  'feature': 240,
#  'extraction': 241,
#  'removing': 242,
#  'dependency': 243,
#  'experts': 244,
#  'let’s': 245,
#  'say': 246,
#  'had': 247,
#  'set': 248,
#  'photos': 249,
#  'pets': 250,
#  'wanted': 251,
#  '“cat”': 252,
#  '“dog”': 253,
#  '“hamster”': 254,
#  'et': 255,
#  'cetera': 256,
#  'e': 257,
#  'ears': 258,
#  'important': 259,
#  'distinguish': 260,
#  'hierarchy': 261,
#  'established': 262,
#  'manually': 263,
#  'expert': 264,
#  'fits': 265,
#  'allowing': 266,
#  'about': 267,
#  'photo': 268,
#  'increased': 269,
#  'precision': 270,
#  'models': 271,
#  'capable': 272,
#  'usually': 273,
#  'categorized': 274,
#  'utilizes': 275,
#  'requires': 276,
#  'kind': 277,
#  'label': 278,
#  'correctly': 279,
#  'contrast': 280,
#  'require': 281,
#  'instead': 282,
#  'detects': 283,
#  'clustering': 284,
#  'distinguishing': 285,
#  'characteristics': 286,
#  'become': 287,
#  'action': 288,
#  'environment': 289,
#  'feedback': 290,
#  'order': 291,
#  'maximize': 292,
#  'reward': 293,
#  'attempts': 294,
#  'mimic': 295,
#  'combination': 296,
#  'inputs': 297,
#  'bias': 298,
#  'elements': 299,
#  'work': 300,
#  'describe': 301,
#  'objects': 302,
#  'consist': 303,
#  'interconnected': 304,
#  'nodes': 305,
#  'building': 306,
#  'upon': 307,
#  'previous': 308,
#  'categorization': 309,
#  'progression': 310,
#  'computations': 311,
#  'visible': 312,
#  'ingests': 313,
#  'final': 314,
#  'made': 315,
#  'calculate': 316,
#  'biases': 317,
#  'function': 318,
#  'moving': 319,
#  'backwards': 320,
#  'effort': 321,
#  'train': 322,
#  'allow': 323,
#  'correct': 324,
#  'accordingly': 325,
#  'over': 326,
#  'becomes': 327,
#  'gradually': 328,
#  'above': 329,
#  'describes': 330,
#  'terms': 331,
#  'incredibly': 332,
#  'address': 333,
#  'problems': 334,
#  'convolutional': 335,
#  'cnns': 336,
#  'primarily': 337,
#  'detection': 338,
#  '2015': 339,
#  'cnn': 340,
#  'bested': 341,
#  'challenge': 342,
#  'first': 343,
#  'recurrent': 344,
#  'rnns': 345,
#  'leverages': 346,
#  'sequential': 347,
#  'times': 348,
#  'series': 349,
#  'real': 350,
#  'world': 351,
#  'part': 352,
#  'daily': 353,
#  'but': 354,
#  'cases': 355,
#  'so': 356,
#  'integrated': 357,
#  'unaware': 358,
#  'taking': 359,
#  'place': 360,
#  'background': 361,
#  'examples': 362,
#  'include': 363,
#  'following': 364,
#  'learn': 365,
#  'transactional': 366,
#  'dangerous': 367,
#  'indicate': 368,
#  'possible': 369,
#  'fraudulent': 370,
#  'criminal': 371,
#  'activity': 372,
#  'other': 373,
#  'efficiency': 374,
#  'effectiveness': 375,
#  'investigative': 376,
#  'analysis': 377,
#  'extracting': 378,
#  'evidence': 379,
#  'sound': 380,
#  'video': 381,
#  'recordings': 382,
#  'documents': 383,
#  'helps': 384,
#  'quickly': 385,
#  'institutions': 386,
#  'regularly': 387,
#  'predictive': 388,
#  'analytics': 389,
#  'drive': 390,
#  'algorithmic': 391,
#  'trading': 392,
#  'stocks': 393,
#  'business': 394,
#  'risks': 395,
#  'loan': 396,
#  'approvals': 397,
#  'manage': 398,
#  'investment': 399,
#  'portfolios': 400,
#  'clients': 401,
#  'organizations': 402,
#  'incorporate': 403,
#  'technology': 404,
#  'their': 405,
#  'chatbots—used': 406,
#  'variety': 407,
#  'portals—are': 408,
#  'straightforward': 409,
#  'traditional': 410,
#  'chatbots': 411,
#  'even': 412,
#  'visual': 413,
#  'commonly': 414,
#  'found': 415,
#  'call': 416,
#  'center': 417,
#  'menus': 418,
#  'sophisticated': 419,
#  'solutions': 420,
#  'attempt': 421,
#  'ambiguous': 422,
#  'receives': 423,
#  'tries': 424,
#  'answer': 425,
#  'directly': 426,
#  'route': 427,
#  'conversation': 428,
#  'user': 429,
#  'virtual': 430,
#  "apple's": 431,
#  'siri': 432,
#  'amazon': 433,
#  'alexa': 434,
#  'google': 435,
#  'assistant': 436,
#  'extends': 437,
#  'idea': 438,
#  'functionality': 439,
#  'creates': 440,
#  'method': 441,
#  'engage': 442,
#  'personalized': 443,
#  'way': 444,
#  'industry': 445,
#  'has': 446,
#  'benefited': 447,
#  'greatly': 448,
#  'capabilities': 449,
#  'ever': 450,
#  'since': 451,
#  'digitization': 452,
#  'hospital': 453,
#  'records': 454,
#  'support': 455,
#  'medical': 456,
#  'imaging': 457,
#  'specialists': 458,
#  'radiologists': 459,
#  'helping': 460,
#  'less': 461}

# %%
len(tokenizer.word_index)
# Out:
# 461

# %%
input_sequences = []
for sentence in text.split('\n'):
  tokenize_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1, len(tokenize_sentence)):
    input_sequences.append(tokenize_sentence[:i+1])

# %%
input_sequences
# Out:
# [[162, 13],
#  [162, 13, 5],
#  [162, 13, 5, 3],
#  [5, 3],
#  [5, 3, 13],
#  [5, 3, 13, 7],
#  [5, 3, 13, 7, 72],
#  [5, 3, 13, 7, 72, 4],
#  [5, 3, 13, 7, 72, 4, 18],
#  [5, 3, 13, 7, 72, 4, 18, 3],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39, 5],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39, 5, 10],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39, 5, 10, 22],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39, 5, 10, 22, 6],
#  [5, 3, 13, 7, 72, 4, 18, 3, 15, 73, 163, 164, 10, 22, 39, 5, 10, 22, 6, 165],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170,
#   53],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170,
#   53,
#   8],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170,
#   53,
#   8,
#   77],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170,
#   53,
#   8,
#   77,
#   78],
#  [5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   15,
#   73,
#   163,
#   164,
#   10,
#   22,
#   39,
#   5,
#   10,
#   22,
#   6,
#   165,
#   2,
#   52,
#   166,
#   167,
#   168,
#   4,
#   2,
#   19,
#   74,
#   27,
#   75,
#   4,
#   5,
#   3,
#   169,
#   40,
#   4,
#   2,
#   76,
#   170,
#   53,
#   8,
#   77,
#   78,
#   171],
#  [20, 172],
#  [20, 172, 173],
#  [20, 172, 173, 7],
#  [20, 172, 173, 7, 5],
#  [20, 172, 173, 7, 5, 10],
#  [20, 172, 173, 7, 5, 10, 17],
#  [20, 172, 173, 7, 5, 10, 17, 14],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41, 175],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41, 175, 14],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41, 175, 14, 23],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41, 175, 14, 23, 24],
#  [20, 172, 173, 7, 5, 10, 17, 14, 174, 13, 7, 10, 17, 41, 175, 14, 23, 24, 8],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88,
#   188],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88,
#   188,
#   189],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88,
#   188,
#   189,
#   16],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88,
#   188,
#   189,
#   16,
#   190],
#  [20,
#   172,
#   173,
#   7,
#   5,
#   10,
#   17,
#   14,
#   174,
#   13,
#   7,
#   10,
#   17,
#   41,
#   175,
#   14,
#   23,
#   24,
#   8,
#   176,
#   40,
#   79,
#   177,
#   54,
#   23,
#   24,
#   79,
#   11,
#   178,
#   42,
#   80,
#   81,
#   4,
#   9,
#   6,
#   82,
#   1,
#   83,
#   179,
#   84,
#   34,
#   1,
#   180,
#   181,
#   182,
#   1,
#   28,
#   29,
#   1,
#   85,
#   183,
#   7,
#   184,
#   43,
#   10,
#   17,
#   25,
#   28,
#   185,
#   186,
#   29,
#   1,
#   85,
#   2,
#   187,
#   24,
#   8,
#   7,
#   5,
#   10,
#   17,
#   86,
#   87,
#   1,
#   88,
#   188,
#   189,
#   16,
#   190,
#   89],
#  [5, 3],
#  [5, 3, 191],
#  [5, 3, 191, 54],
#  [5, 3, 191, 54, 21],
#  [5, 3, 191, 54, 21, 1],
#  [5, 3, 191, 54, 21, 1, 44],
#  [5, 3, 191, 54, 21, 1, 44, 15],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194, 92],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194, 92, 195],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194, 92, 195, 19],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194, 92, 195, 19, 93],
#  [5, 3, 191, 54, 21, 1, 44, 15, 90, 192, 91, 193, 1, 194, 92, 195, 19, 93, 12],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211,
#   212],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211,
#   212,
#   213],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211,
#   212,
#   213,
#   1],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211,
#   212,
#   213,
#   1,
#   214],
#  [5,
#   3,
#   191,
#   54,
#   21,
#   1,
#   44,
#   15,
#   90,
#   192,
#   91,
#   193,
#   1,
#   194,
#   92,
#   195,
#   19,
#   93,
#   12,
#   196,
#   197,
#   198,
#   94,
#   1,
#   199,
#   95,
#   200,
#   96,
#   201,
#   202,
#   203,
#   204,
#   97,
#   205,
#   98,
#   206,
#   55,
#   35,
#   207,
#   208,
#   209,
#   210,
#   35,
#   211,
#   212,
#   213,
#   1,
#   214,
#   53],
#  [5, 3],
#  [5, 3, 215],
#  [5, 3, 215, 18],
#  [5, 3, 215, 18, 3],
#  [56, 5],
#  [56, 5, 3],
#  [56, 5, 3, 13],
#  [56, 5, 3, 13, 7],
#  [56, 5, 3, 13, 7, 72],
#  [56, 5, 3, 13, 7, 72, 4],
#  [56, 5, 3, 13, 7, 72, 4, 18],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5, 3],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5, 3, 218],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5, 3, 218, 101],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5, 3, 218, 101, 30],
#  [56, 5, 3, 13, 7, 72, 4, 18, 3, 99, 216, 100, 217, 5, 3, 218, 101, 30, 219],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2,
#   220],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2,
#   220,
#   8],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2,
#   220,
#   8,
#   36],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2,
#   220,
#   8,
#   36,
#   12],
#  [56,
#   5,
#   3,
#   13,
#   7,
#   72,
#   4,
#   18,
#   3,
#   99,
#   216,
#   100,
#   217,
#   5,
#   3,
#   218,
#   101,
#   30,
#   219,
#   18,
#   3,
#   20,
#   2,
#   102,
#   4,
#   9,
#   15,
#   12,
#   103,
#   41,
#   1,
#   2,
#   220,
#   8,
#   36,
#   12,
#   104],
#  [18, 3],
#  [18, 3, 31],
#  [18, 3, 31, 221],
#  [18, 3, 31, 221, 105],
#  [18, 3, 31, 221, 105, 57],
#  [18, 3, 31, 221, 105, 57, 9],
#  [18, 3, 31, 221, 105, 57, 9, 6],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11, 223],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11, 223, 30],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11, 223, 30, 2],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11, 223, 30, 2, 46],
#  [18, 3, 31, 221, 105, 57, 9, 6, 28, 222, 15, 106, 45, 11, 223, 30, 2, 46, 9],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233,
#   12],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233,
#   12,
#   48],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233,
#   12,
#   48,
#   7],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233,
#   12,
#   48,
#   7,
#   105],
#  [18,
#   3,
#   31,
#   221,
#   105,
#   57,
#   9,
#   6,
#   28,
#   222,
#   15,
#   106,
#   45,
#   11,
#   223,
#   30,
#   2,
#   46,
#   9,
#   16,
#   2,
#   47,
#   1,
#   224,
#   48,
#   225,
#   37,
#   58,
#   226,
#   227,
#   15,
#   12,
#   58,
#   59,
#   107,
#   9,
#   12,
#   228,
#   229,
#   15,
#   56,
#   12,
#   230,
#   12,
#   231,
#   232,
#   32,
#   27,
#   108,
#   49,
#   6,
#   233,
#   12,
#   48,
#   7,
#   105,
#   234],
#  [5, 3],
#  [5, 3, 235],
#  [5, 3, 235, 27],
#  [5, 3, 235, 27, 4],
#  [5, 3, 235, 27, 4, 9],
#  [5, 3, 235, 27, 4, 9, 108],
#  [5, 3, 235, 27, 4, 9, 108, 49],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18, 3],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18, 3, 50],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18, 3, 50, 31],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18, 3, 50, 31, 25],
#  [5, 3, 235, 27, 4, 9, 108, 49, 15, 13, 109, 236, 41, 18, 3, 50, 31, 25, 237],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9,
#   38],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9,
#   38,
#   238],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9,
#   38,
#   238,
#   1],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9,
#   38,
#   238,
#   1,
#   51],
#  [5,
#   3,
#   235,
#   27,
#   4,
#   9,
#   108,
#   49,
#   15,
#   13,
#   109,
#   236,
#   41,
#   18,
#   3,
#   50,
#   31,
#   25,
#   237,
#   1,
#   60,
#   107,
#   9,
#   38,
#   238,
#   1,
#   51,
#   1],
#  [5,
#   3,
#   235,
# ...
#   413,
#   26,
#   414,
#   415,
#   8],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426,
#   14],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426,
#   14,
#   427],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426,
#   14,
#   427,
#   2],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426,
#   14,
#   427,
#   2,
#   428],
#  [54,
#   402,
#   403,
#   5,
#   3,
#   404,
#   48,
#   405,
#   69,
#   70,
#   117,
#   406,
#   8,
#   7,
#   407,
#   4,
#   21,
#   44,
#   1,
#   69,
#   70,
#   408,
#   7,
#   409,
#   75,
#   4,
#   53,
#   410,
#   411,
#   59,
#   152,
#   153,
#   1,
#   412,
#   413,
#   26,
#   414,
#   415,
#   8,
#   416,
#   417,
#   38,
#   418,
#   144,
#   23,
#   419,
#   71,
#   420,
#   421,
#   6,
#   113,
#   32,
#   3,
#   56,
#   145,
#   11,
#   135,
#   159,
#   6,
#   422,
#   160,
#   130,
#   42,
#   2,
#   159,
#   12,
#   423,
#   2,
#   71,
#   62,
#   424,
#   6,
#   425,
#   50,
#   160,
#   426,
#   14,
#   427,
#   2,
#   428,
#   6],
#  ...]

# %%
max_len = max([len(x) for x in input_sequences])
max_len
# Out:
# 101

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0, 162,  13],
#        [  0,   0,   0, ..., 162,  13,   5],
#        [  0,   0,   0, ...,  13,   5,   3],
#        ...,
#        [  0,   0,   0, ...,  23,  51,   8],
#        [  0,   0,   0, ...,  51,   8, 461],
#        [  0,   0,   0, ...,   8, 461,  65]], dtype=int32)

# %%
padded_input_sequences.shape
# Out:
# (1073, 101)

# %%
X = padded_input_sequences[:, :-1]
X.shape
# Out:
# (1073, 100)

# %%
y = padded_input_sequences[:, -1]
y.shape
# Out:
# (1073,)

# %%
y = to_categorical(y, num_classes=462)

# %%
y.shape
# Out:
# (1073, 462)

# %%
model = Sequential()
model.add(Embedding(462, 100, input_length=100))
model.add(LSTM(170))
model.add(Dense(462, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 100)          46200
#
#  lstm_2 (LSTM)               (None, 170)               184280
#
#  dense_2 (Dense)             (None, 462)               79002
#
# =================================================================
# Total params: 309482 (1.18 MB)
# Trainable params: 309482 (1.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 5s 97ms/step - loss: 5.9784 - accuracy: 0.0280
# Epoch 2/100
# 34/34 [==============================] - 3s 83ms/step - loss: 5.5944 - accuracy: 0.0457
# Epoch 3/100
# 34/34 [==============================] - 1s 42ms/step - loss: 5.5085 - accuracy: 0.0466
# Epoch 4/100
# 34/34 [==============================] - 1s 35ms/step - loss: 5.4564 - accuracy: 0.0606
# Epoch 5/100
# 34/34 [==============================] - 1s 23ms/step - loss: 5.3852 - accuracy: 0.0755
# Epoch 6/100
# 34/34 [==============================] - 1s 30ms/step - loss: 5.2727 - accuracy: 0.0736
# Epoch 7/100
# 34/34 [==============================] - 1s 23ms/step - loss: 5.1391 - accuracy: 0.0867
# Epoch 8/100
# 34/34 [==============================] - 1s 19ms/step - loss: 4.9790 - accuracy: 0.0969
# Epoch 9/100
# 34/34 [==============================] - 1s 15ms/step - loss: 4.8055 - accuracy: 0.1165
# Epoch 10/100
# 34/34 [==============================] - 1s 18ms/step - loss: 4.6150 - accuracy: 0.1305
# Epoch 11/100
# 34/34 [==============================] - 1s 22ms/step - loss: 4.4098 - accuracy: 0.1473
# Epoch 12/100
# 34/34 [==============================] - 1s 18ms/step - loss: 4.1843 - accuracy: 0.1836
# Epoch 13/100
# 34/34 [==============================] - 0s 14ms/step - loss: 3.9663 - accuracy: 0.1976
# Epoch 14/100
# 34/34 [==============================] - 1s 33ms/step - loss: 3.7362 - accuracy: 0.2134
# Epoch 15/100
# 34/34 [==============================] - 1s 16ms/step - loss: 3.5050 - accuracy: 0.2759
# Epoch 16/100
# 34/34 [==============================] - 1s 20ms/step - loss: 3.2784 - accuracy: 0.2889
# Epoch 17/100
# 34/34 [==============================] - 1s 27ms/step - loss: 3.0564 - accuracy: 0.3402
# Epoch 18/100
# 34/34 [==============================] - 0s 12ms/step - loss: 2.8465 - accuracy: 0.3830
# Epoch 19/100
# 34/34 [==============================] - 0s 13ms/step - loss: 2.6420 - accuracy: 0.4334
# Epoch 20/100
# 34/34 [==============================] - 1s 17ms/step - loss: 2.4430 - accuracy: 0.4790
# Epoch 21/100
# 34/34 [==============================] - 0s 11ms/step - loss: 2.2472 - accuracy: 0.5480
# Epoch 22/100
# 34/34 [==============================] - 1s 15ms/step - loss: 2.0693 - accuracy: 0.5937
# Epoch 23/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.9118 - accuracy: 0.6412
# Epoch 24/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7553 - accuracy: 0.7064
# Epoch 25/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.5961 - accuracy: 0.7661
# Epoch 26/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.4583 - accuracy: 0.7819
# Epoch 27/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.3329 - accuracy: 0.8201
# Epoch 28/100
# 34/34 [==============================] - 0s 10ms/step - loss: 1.2167 - accuracy: 0.8574
# Epoch 29/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.1122 - accuracy: 0.8742
# Epoch 30/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.0125 - accuracy: 0.8928
# Epoch 31/100
# 34/34 [==============================] - 0s 13ms/step - loss: 0.9165 - accuracy: 0.9320
# Epoch 32/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8349 - accuracy: 0.9376
# Epoch 33/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.7684 - accuracy: 0.9515
# Epoch 34/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.7019 - accuracy: 0.9553
# Epoch 35/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.6377 - accuracy: 0.9599
# Epoch 36/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.5854 - accuracy: 0.9599
# Epoch 37/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.5387 - accuracy: 0.9674
# Epoch 38/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.4930 - accuracy: 0.9702
# Epoch 39/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4570 - accuracy: 0.9730
# Epoch 40/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.4225 - accuracy: 0.9767
# Epoch 41/100
# 34/34 [==============================] - 1s 16ms/step - loss: 0.3914 - accuracy: 0.9795
# Epoch 42/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3609 - accuracy: 0.9804
# Epoch 43/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.3371 - accuracy: 0.9804
# Epoch 44/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.3134 - accuracy: 0.9814
# Epoch 45/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.2922 - accuracy: 0.9832
# Epoch 46/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.2752 - accuracy: 0.9842
# Epoch 47/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.2569 - accuracy: 0.9842
# Epoch 48/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.2409 - accuracy: 0.9860
# Epoch 49/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.2267 - accuracy: 0.9842
# Epoch 50/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.2145 - accuracy: 0.9860
# Epoch 51/100
# 34/34 [==============================] - 0s 13ms/step - loss: 0.2029 - accuracy: 0.9888
# Epoch 52/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1920 - accuracy: 0.9860
# Epoch 53/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1815 - accuracy: 0.9879
# Epoch 54/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.1728 - accuracy: 0.9860
# Epoch 55/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1627 - accuracy: 0.9879
# Epoch 56/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1556 - accuracy: 0.9870
# Epoch 57/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.1494 - accuracy: 0.9860
# Epoch 58/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.1425 - accuracy: 0.9888
# Epoch 59/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1357 - accuracy: 0.9860
# Epoch 60/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.1310 - accuracy: 0.9870
# Epoch 61/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.9888
# Epoch 62/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1206 - accuracy: 0.9870
# Epoch 63/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1161 - accuracy: 0.9879
# Epoch 64/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.1121 - accuracy: 0.9888
# Epoch 65/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1080 - accuracy: 0.9870
# Epoch 66/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.1032 - accuracy: 0.9888
# Epoch 67/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0999 - accuracy: 0.9879
# Epoch 68/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0966 - accuracy: 0.9860
# Epoch 69/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0943 - accuracy: 0.9888
# Epoch 70/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0907 - accuracy: 0.9897
# Epoch 71/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0888 - accuracy: 0.9879
# Epoch 72/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0857 - accuracy: 0.9870
# Epoch 73/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0842 - accuracy: 0.9851
# Epoch 74/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0811 - accuracy: 0.9888
# Epoch 75/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0795 - accuracy: 0.9870
# Epoch 76/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0767 - accuracy: 0.9888
# Epoch 77/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0747 - accuracy: 0.9870
# Epoch 78/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0723 - accuracy: 0.9879
# Epoch 79/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0707 - accuracy: 0.9879
# Epoch 80/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0688 - accuracy: 0.9879
# Epoch 81/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0684 - accuracy: 0.9879
# Epoch 82/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0670 - accuracy: 0.9870
# Epoch 83/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0649 - accuracy: 0.9888
# Epoch 84/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9879
# Epoch 85/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0632 - accuracy: 0.9888
# Epoch 86/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0609 - accuracy: 0.9870
# Epoch 87/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0592 - accuracy: 0.9879
# Epoch 88/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9870
# Epoch 89/100
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0576 - accuracy: 0.9888
# Epoch 90/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0564 - accuracy: 0.9870
# Epoch 91/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0553 - accuracy: 0.9879
# Epoch 92/100
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0545 - accuracy: 0.9879
# Epoch 93/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0522 - accuracy: 0.9888
# Epoch 94/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0516 - accuracy: 0.9888
# Epoch 95/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0514 - accuracy: 0.9888
# Epoch 96/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.0497 - accuracy: 0.9888
# Epoch 97/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0494 - accuracy: 0.9897
# Epoch 98/100
# 34/34 [==============================] - 0s 8ms/step - loss: 0.0501 - accuracy: 0.9888
# Epoch 99/100
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0479 - accuracy: 0.9888
# Epoch 100/100
# 34/34 [==============================] - 0s 7ms/step - loss: 0.0465 - accuracy: 0.9888

# %%
import time

text = "By strict definition"

for i in range(20):
  #tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]

  #padding
  padded_token_text = pad_sequences([token_text], maxlen=100, padding='pre')

  #predict
  pos = np.argmax(model.predict(padded_token_text))

  for word, index in tokenizer.word_index.items():
    if index == pos:
      text = text + ' ' + word
      print(text)
      time.sleep(1)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# By strict definition a
# 1/1 [==============================] - 0s 23ms/step
# By strict definition a deep
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural
# 1/1 [==============================] - 0s 20ms/step
# By strict definition a deep neural network
# 1/1 [==============================] - 0s 18ms/step
# By strict definition a deep neural network or
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural
# 1/1 [==============================] - 0s 32ms/step
# By strict definition a deep neural network or dnn is a neural network
# 1/1 [==============================] - 0s 30ms/step
# By strict definition a deep neural network or dnn is a neural network with
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three
# 1/1 [==============================] - 0s 18ms/step
# By strict definition a deep neural network or dnn is a neural network with three or
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers in
# 1/1 [==============================] - 0s 21ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers in practice
# 1/1 [==============================] - 0s 20ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers in practice most
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers in practice most dnns
# 1/1 [==============================] - 0s 19ms/step
# By strict definition a deep neural network or dnn is a neural network with three or more layers in practice most dnns have
